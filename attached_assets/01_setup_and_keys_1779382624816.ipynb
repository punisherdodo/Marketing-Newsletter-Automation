# %%
from pathlib import Path

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

env_example_text = """OPENAI_API_KEY=your_openai_api_key
HUBSPOT_ACCESS_TOKEN=your_hubspot_developer_platform_private_app_token
OPENAI_MODEL=gpt-5.4
"""

print("Project root:", root)
print("\nIf you have not created a .env file yet, create one in the project root with this format:\n")
print(env_example_text)

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
load_dotenv(root / ".env", override=True)

print("OpenAI key loaded:", bool(os.getenv("OPENAI_API_KEY")))
print("HubSpot token loaded:", bool(os.getenv("HUBSPOT_ACCESS_TOKEN")))
print("Model:", os.getenv("OPENAI_MODEL"))
# Out:
# OpenAI key loaded: True
# HubSpot token loaded: True
# Model: gpt-5.4

# %%
import os
from openai import OpenAI
from pathlib import Path
from dotenv import load_dotenv

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
load_dotenv(root / ".env", override=True)

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model=os.getenv("OPENAI_MODEL", "gpt-5.4"),
    input="Reply with exactly these 4 words: OpenAI key works fine"
)

print(response.output_text)
# Out:
# OpenAI key works fine

# %%
import os
import requests
from pathlib import Path
from dotenv import load_dotenv

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
load_dotenv(root / ".env", override=True)

hubspot_token = os.getenv("HUBSPOT_ACCESS_TOKEN")

url = "https://api.hubapi.com/crm/v3/objects/contacts?limit=1"
headers = {
    "Authorization": f"Bearer {hubspot_token}",
    "Content-Type": "application/json"
}

response = requests.get(url, headers=headers)

print("Status code:", response.status_code)
print(response.text[:1000])
# Out:
# Status code: 200
# {"results":[{"id":"470819398349","properties":{"createdate":"2026-04-14T01:49:31.397Z","email":"emailmaria@hubspot.com","firstname":"Maria","hs_object_id":"470819398349","lastmodifieddate":"2026-04-14T01:50:41.311Z","lastname":"Johnson (Sample Contact)"},"createdAt":"2026-04-14T01:49:31.397Z","updatedAt":"2026-04-14T01:50:41.311Z","archived":false,"url":"https://app-na2.hubspot.com/contacts/245898264/record/0-1/470819398349"}],"paging":{"next":{"after":"470819398350","link":"https://api.hubapi.com/crm/objects/v3/contacts?limit=1&after=470819398350"}}}
